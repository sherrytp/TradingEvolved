# %% [markdown]
# ### setting

# %% [raw]
# trading_calendars\trading_calendar.py
# 	start_default '1990-01-01' or earlier
#
# ~/.zipline/extension.py
# 	import pandas as pd
# 	from zipline.data.bundles import register
# from zipline.data.bundles.csvdir import csvdir_equities
#
# 	start_session = pd.Timestamp('1990-1-2', tz='utc') ##  the same as csv data date
# end_session = pd.Timestamp(datetime.date.today().isoformat(),tz='utc')
# 	register(
#     'custom-csvdir-bundle',
#     csvdir_equities(
#         ['daily'],
#         '/path/to/your/csvs',
#     ),
#     calendar_name='NYSE', # US equities
#     start_session=start_session,
#     end_session=end_session
# )
#
#
# 	Get all registered calendars with get_calendar_names:
# 	tc.get_calendar_names()[:5]
# ['XPHS', 'FWB', 'CFE', 'CMES', 'XSGO']
# 	Get a calendar with get_calendar:
# 	xnys = tc.get_calendar("XNYS")

# %% [markdown]
# ##  ingest

# %%
#!zipline bundles

# %%
#!zipline clean -b mybundle --before 2020-12-10

# %%
# !zipline ingest -b mybundle
# Out:
# [2020-12-10 01:48:10.946226] INFO: zipline.data.bundles.core: Ingesting mybundle.
#  | AAPL: sid 0
# /zipline/zipline/data/bcolz_daily_bars.py:367: UserWarning: Ignoring 1 values because they are out of bounds for uint32:               open    high     low   close        volume  dividend  split
# date
# 2000-09-29  0.5033  0.5179  0.4531  0.4598  7.421640e+09         0      1
#   winsorise_uint32(raw_data, invalid_data_behavior, 'volume', *OHLC)
#  | ACWI: sid 1
#  | ADBE: sid 2
#  | ADI: sid 3
#  | ADP: sid 4
#  | ADSK: sid 5
#  | ALGN: sid 6
#  | ALXN: sid 7
#  | AMAT: sid 8
#  | AMD: sid 9
#  | AMGN: sid 10
#  | AMZN: sid 11
#  | ANSS: sid 12
#  | ASML: sid 13
# Loading custom pricing data:   [##----------------------------------]    6% | AVGO: sid 14
# Merging daily equity files:  [------------------------------------]  14 | AXP: sid 15
# Loading custom pricing data:   [##----------------------------------]    7% | BA: sid 16
# ...

# %% [markdown]
# ## simple test

# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
# %%zipline --start 2000-1-5 --end 2020-10-29 --capital-base 10000 --bundle mybundle -o buy_and_hold.pkl --trading-calendar NYSE
#
# # imports
# from zipline.api import order, symbol, record, set_benchmark
#
# # parameters
# selected_stock = 'SPY'
# n_stocks_to_buy = 10
#
# def initialize(context):
#     set_benchmark(symbol('SPY'))
#     context.asset = symbol('TSLA')
#     context.has_ordered = False
#
# def handle_data(context, data):
#     # record price for further inspection
#     record(price=data.current(symbol(selected_stock), 'price'))
#
#     # trading logic
#     if not context.has_ordered:
#         # placing order, negative number for sale/short
#         order(symbol(selected_stock), n_stocks_to_buy)
#         # setting up a flag for holding a position
#         context.has_ordered = True
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2000-01-05 21:00:00+00:00              NaN                 0.000000       NaN
# 2000-01-06 21:00:00+00:00         0.000784                -0.000070 -0.001762
# 2000-01-07 21:00:00+00:00         0.073649                 0.007930  0.266409
# 2000-01-10 21:00:00+00:00         0.062503                 0.008430  0.192867
# 2000-01-11 21:00:00+00:00         0.060613                 0.006680  0.122840
# 2000-01-12 21:00:00+00:00         0.057102                 0.005242  0.089855
# 2000-01-13 21:00:00+00:00         0.052507                 0.007180  0.085034
# 2000-01-14 21:00:00+00:00         0.048890                 0.009149  0.082261
# 2000-01-18 21:00:00+00:00         0.047310                 0.007992  0.066364
# 2000-01-19 21:00:00+00:00         0.044628                 0.009180  0.063279
# 2000-01-20 21:00:00+00:00         0.044938                 0.006930  0.048882
# ...
